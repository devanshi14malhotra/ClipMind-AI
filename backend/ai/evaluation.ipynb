# %% [markdown]
# # ClipMind AI - Performance Evaluation

# %%
import time
import sys
import os
sys.path.append(os.path.abspath('..'))
from ai.api_client import _groq_summarize

sample_transcript = """
Artificial intelligence is rapidly transforming the modern world. From self-driving cars to virtual assistants on our phones, AI is fundamentally changing how we interact with technology and making our daily workflows significantly more efficient. One of the most exciting and rapidly developing subfields in Artificial Intelligence is Natural Language Processing, commonly referred to as NLP. NLP allows computers to understand, interpret, and even generate human language in a way that is both meaningful and contextually accurate. This underlying technology is exactly what powers intelligent chatbots, real-time language translation services, and even advanced video summarization platforms like ClipMind.
"""
print("Loaded dependencies & sample text.")
# Out:
# Loaded dependencies & sample text.

# %%
print("Running Cloud AI Summarization Evaluation...")
start_time = time.time()
groq_results = _groq_summarize(sample_transcript)
end_time = time.time()

print("\n" + "="*50)
print(f"GROQ AI GENERATED SUMMARY:\n{groq_results['summary']}")
print("="*50)
print(f"Processing Time: {end_time - start_time:.2f} seconds ⚡ (Extremely Fast)")
print("="*50)
# Out:
# Running Cloud AI Summarization Evaluation...
#
# ...
# GROQ AI GENERATED SUMMARY:
# Artificial intelligence is transforming the modern world by making daily workflows more efficient, with Natural Language Processing (NLP) being a rapidly developing subfield that enables computers to understand and generate human language.
# ...
# Processing Time: 0.72 seconds ⚡ (Extremely Fast)
# ...
